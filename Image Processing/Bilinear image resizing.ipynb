# %%
from skimage import io, transform
from matplotlib import pyplot as plt
import numpy as np
import math as math

# %%
waterfall = io.imread("aguaazul.jpg")
plt.imshow(waterfall)

# %%
dummy = transform.resize( waterfall, (12,24))
plt.imshow(dummy)
